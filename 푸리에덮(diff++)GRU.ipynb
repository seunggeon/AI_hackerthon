# %% [markdown]
# <a href="https://colab.research.google.com/github/macho-yoo/KW_AI_Hackathon/blob/main/%ED%91%B8%EB%A6%AC%EC%97%90%EB%8D%AE(diff%2B%2B)GRU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/월간 11 운동')

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold
from scipy.stats import skew
from scipy.stats import kurtosis
from sklearn.cluster import KMeans
import math
from tqdm import tqdm
from scipy import fftpack
from numpy.fft import *
# 무시
pd.set_option('mode.chained_assignment',  None) # <==== 경고를 끈다

train = pd.read_csv('train_features.csv')


train_label = pd.read_csv('train_labels.csv')
train_y = train_label.label

test = pd.read_csv('test_features.csv')
submission=pd.read_csv('sample_submission.csv')

# %%
import scipy
# !pip install transforms3d
from transforms3d.axangles import axangle2mat

def rolling(data):
    for j in np.random.choice(data.shape[0], int(data.shape[0]*2/3)):
        data[j] = np.roll(data[j], np.random.choice(data.shape[1]), axis= 0)
    return data

def rotation(data):
    axis = np.random.uniform(low=-1, high=1, size=data.shape[1])
    angle = np.random.uniform(low=-np.pi, high=np.pi)

    return np.matmul(data , axangle2mat(axis,angle))

def permutation(data, nPerm=4, mSL=10):
    data_new = np.zeros(data.shape)
    idx = np.random.permutation(nPerm)
    bWhile = True
    while bWhile == True:
        segs = np.zeros(nPerm+1, dtype=int)
        segs[1:-1] = np.sort(np.random.randint(mSL, data.shape[0]-mSL, nPerm-1))
        segs[-1] = data.shape[0]
        if np.min(segs[1:]-segs[0:-1]) > mSL:
            bWhile = False
    pp = 0
    for ii in range(nPerm):
        data_temp = data[segs[idx[ii]]:segs[idx[ii]+1],:]
        data_new[pp:pp+len(data_temp),:] = data_temp
        pp += len(data_temp)
    return(data_new)


def Jitter(data, sigma=0.05):
    myNoise = np.random.normal(loc=0, scale=sigma, size=data.shape)
    return data+myNoise


def combine_aug(data, k, aug_P = 0):
    data_ = data.copy()
    if aug_P == 0:
        if (k+1) % 2 == 0:
            for i in np.random.choice(int(data.shape[0]/600), int(data.shape[0]/600*2/3)):
                data_[600*i:600*(i+1)] = rotation(np.array(data_[600*i:600*(i+1)]))
        if (k+1) % 2 == 1:
            for i in np.random.choice(int(data.shape[0]/600), int(data.shape[0]/600*2/3)):
                data_[600*i:600*(i+1)] = permutation(np.array(data_[600*i:600*(i+1)]))
    if aug_P != 0:
        pass
    return data_
# Out:
# Collecting transforms3d
#   Downloading transforms3d-0.3.1.tar.gz (62 kB)
#      |████████████████████████████████| 62 kB 1.2 MB/s
# Building wheels for collected packages: transforms3d
#   Building wheel for transforms3d (setup.py) ... done
#   Created wheel for transforms3d: filename=transforms3d-0.3.1-py3-none-any.whl size=59373 sha256=f38afb784a14f2bd8469f1dd9d9a370c47e66f078de2e990e43fa536d254ef83
#   Stored in directory: /root/.cache/pip/wheels/b5/b7/93/8985551f83720ce37548a5b543c75380bb707955a9c2c5d28c
# Successfully built transforms3d
# Installing collected packages: transforms3d
# Successfully installed transforms3d-0.3.1

# %% [markdown]
# 데이터 변수 증가

# %%
pi = math.pi
dt=0.02 
from math import atan, sqrt

def roll_pitch(data):
    roll = (data.iloc[:,1]/(data.iloc[:,0]**2 + data.iloc[:,2]**2).apply(lambda x : sqrt(x))).apply(lambda x : atan(x))*180/np.pi
    pitch = (data.iloc[:,0]/(data.iloc[:,1]**2 + data.iloc[:,2]**2).apply(lambda x : sqrt(x))).apply(lambda x : atan(x))*180/np.pi
    return pd.concat([roll,pitch], axis=1)

# 원본데이터를 에너지값으로 표현
def get_energy(data):
    energy_ = (data.iloc[:,0]**2+data.iloc[:,1]**2+data.iloc[:,2]**2)**(1/3)
    return energy_ 

def get_energy_between(data,data_):
   energy_between = ((data.iloc[:,0]-data_.iloc[:,0])**2+(data.iloc[:,1]-data_.iloc[:,1])**2+(data.iloc[:,2]-data_.iloc[:,2])**2)**(1/3)
   return energy_between

def setting(data, data_):
 
    for i in range(0, data.shape[0], 600):
         data[i] = data_[i] - data_[i+599]

    return data
        
def get_diff(data):
        x_dif, y_dif, z_dif = data.iloc[:, 0].diff(), data.iloc[:, 1].diff(), data.iloc[:, 2].diff()
        return pd.concat([setting(x_dif, data.iloc[:, 0]),
                      setting(y_dif, data.iloc[:, 1]),
                      setting(z_dif, data.iloc[:, 2])], axis= 1)
def fourier_transform_one_signal(t_signal):
    complex_f_signal= fftpack.fft(t_signal)
    amplitude_f_signal=np.abs(complex_f_signal)
    return amplitude_f_signal

def get_fourier(data):
  fft=[]
  for i in data['id'].unique():
    temp=data.loc[data['id']==i]
    for i in data.columns[2:8]:
        temp[i]=fourier_transform_one_signal(temp[i].values)
    fft.append(temp)
  return pd.concat(fft)

# %%
def train_dataset(data, i, aug_P = 0):

    acc_data=data.iloc[:,2:5]
    gy_data=data.iloc[:,5:8]
 
    aug_acc = combine_aug(acc_data, i, aug_P)
    aug_gy = combine_aug(gy_data, i, aug_P)

    energy_acc = get_energy(aug_acc)
    energy_gy  = get_energy(aug_gy)

    diff_acc = get_diff(aug_acc)
    diff_gy = get_diff(aug_gy)

    roll_pitch_acc = roll_pitch(aug_acc)
    roll_pitch_gy = roll_pitch(aug_gy)
    
    energy_acc_gy = get_energy_between(aug_acc, aug_gy)
    
    data_id_time=data.iloc[:,0:2]
    aug_data=pd.concat([data_id_time,aug_acc,aug_gy],axis=1)

    acc_gy_fourier=get_fourier(aug_data)


    return pd.concat([acc_gy_fourier,diff_acc,energy_acc, roll_pitch_acc, diff_gy,energy_gy,  roll_pitch_gy, energy_acc_gy], axis= 1)


def test_dataset(data):

    acc_data=data.iloc[:,2:5]
    gy_data=data.iloc[:,5:8]

    roll_pitch_acc = roll_pitch(acc_data)
    roll_pitch_gy = roll_pitch(gy_data)

    energy_acc = get_energy(acc_data)
    energy_gy  = get_energy(gy_data)

    diff_acc = get_diff(acc_data)
    diff_gy = get_diff(gy_data)

    energy_acc_gy = get_energy_between(acc_data, gy_data)
    
    acc_gy_fourier=get_fourier(data)

    return pd.concat([acc_gy_fourier,diff_acc,energy_acc,  roll_pitch_acc, diff_gy,energy_gy, roll_pitch_gy, energy_acc_gy], axis= 1)

# %% [markdown]
# 스케일러

# %%
import sklearn
from sklearn.preprocessing import StandardScaler

data_for_scaler = test_dataset(train).iloc[:,2:]
scaler = StandardScaler().fit(np.array(data_for_scaler))

data_for_scaler = np.array(data_for_scaler).reshape(-1, 600, data_for_scaler.shape[1])
########################################################################################
test_x = test_dataset(test).iloc[:,2:]

test_X = scaler.transform(np.array(test_x)).reshape(-1, 600, test_x.shape[1])

# %% [markdown]
# 모델링 및 학습

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers as L

from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
"""def first_model():
    inputs = L.Input(shape = (data_for_scaler.shape[1], data_for_scaler.shape[2]))
    gru1 = L.GRU(256, return_sequences = True, dropout = 0.2)(inputs)
    mp = L.MaxPool1D()(gru1)
    ap = L.AveragePooling1D()(gru1)
    concat1 = L.Concatenate()([mp, ap])
    gru2 = L.GRU(256, return_sequences = True, dropout = 0.2)(concat1)
    GAP = L.GlobalAveragePooling1D()(gru2)
    dense = L.Dense(61, activation = "softmax")(GAP)
    return keras.models.Model(inputs, dense)
"""

# %%
def first_model():
    inputs = L.Input(shape = (data_for_scaler.shape[1], data_for_scaler.shape[2]))
    gru1 = L.GRU(256, return_sequences = True, dropout = 0.2)(inputs)
    ap = L.AveragePooling1D()(gru1)
    gru2 = L.GRU(150, return_sequences = True)(ap)
    GAP = L.GlobalAveragePooling1D()(gru2)
    dense = L.Dense(61, activation = "softmax")(GAP)
    return keras.models.Model(inputs, dense)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
import random

def train_model(model_ = None, epochs = 40, first_rlr = 15, second_rlr = 30, r_seed = 10, aug_P = 0, seed_ = 1):
    # first_rlr : 첫번째로 learning_rate이 감소
    # second_rlr : 두번째로 learning_rate이 감소
    # r_seed : StratifiedKFold seed
    # seed_ : numpy/random seed
    
    result_model = []
    cnt = 0
    train_reshape = np.array(train).reshape(-1,600,8)

    #train_reshape_acc = np.array(train_acc).reshape(-1, 600, 3)
    #train_reshape_gy = np.array(train_gy).reshape(-1, 600, 3)
    
    random.seed(seed_)
    tf.random.set_seed(21)

    spliter = StratifiedKFold(n_splits=10, shuffle = True, random_state = r_seed)
    
    for train_split_id, valid_split_id in spliter.split(train_reshape, train_y):
       
        train_Y, valid_Y = np.array(pd.get_dummies(train_label.label))[train_split_id], np.array(pd.get_dummies(train_label.label))[valid_split_id]

        valid_s = train_reshape[valid_split_id].reshape(-1, 8)
        pdvalid_s = pd.DataFrame(valid_s)
        pdvalid_s.rename(columns={0: 'id', 1:'time', 2:0, 3:1, 4:2, 5:3, 6:4, 7:5}, inplace = True)
       
        
        valid_1 = test_dataset(pdvalid_s)
        valid_x = valid_1.iloc[:,2:]
        valid_X = scaler.transform(np.array(valid_x)).reshape(-1, 600, valid_x.shape[1])

        model = model_()
        model.compile(optimizer=keras.optimizers.RMSprop(0.003),
                      loss='categorical_crossentropy', metrics=['accuracy'])
        val_score = 0
        seed_ += 1

        for i in range(epochs):
            
            np.random.seed(seed_*47 + i)
            
            train_s = train_reshape[train_split_id].reshape(-1, 8)
            pdtrain_s = pd.DataFrame(train_s)
            pdtrain_s.rename(columns={0: 'id', 1:'time', 2:0, 3:1, 4:2, 5:3, 6:4, 7:5}, inplace = True)

            train_1 = train_dataset(pdtrain_s, i, aug_P)
            train_x = train_1.iloc[:,2:]
            train_X = scaler.transform(np.array(train_x)).reshape(-1, 600, train_x.shape[1])

            train_X_ = train_X.copy()

            train_X_ = rolling(train_X_)

            hist = model.fit(train_X_, train_Y, epochs = 1, validation_data = (valid_X, valid_Y), verbose = 0)

            train_accuracy = hist.history["accuracy"]
            new_val_score = accuracy_score(np.argmax(valid_Y, axis = 1), np.argmax(model.predict(valid_X), axis = 1))
            val_loss = hist.history["val_loss"]

            if i == first_rlr:
                model.compile(optimizer=keras.optimizers.RMSprop(0.003*0.2),
                              loss='categorical_crossentropy', metrics=['accuracy'])

            if i == second_rlr:
                model.compile(optimizer = keras.optimizers.RMSprop(0.003*0.2*0.4),
                             loss='categorical_crossentropy', metrics=['accuracy'])

            print("epoch {} - train_accuracy : {} - validation_loss : {} - validation_accuracy : {}".format(i,
                                                                                                            train_accuracy,
                                                                                                            val_loss,
                                                                                                            new_val_score,
                                                                                                            ))

            if i == 0:
                val_loss_score = val_loss[0]
        
            if val_loss_score >= val_loss[0]:
                val_loss_score = val_loss[0]
                best_model = model
                print("####best_val####")
                    
            if new_val_score >= val_score:
                val_score = new_val_score
                best_model = model
                print("####best_acc####")
        print("####################################################### cycle {} is done".format(cnt))
        result_model.append(best_model)
        cnt+=1
    return result_model


def predict_(model):
    result = []
    for mod in model:
        result.append(mod.predict(test_X))
    predict = np.array(result).mean(axis = 0)
    return predict

def save_model(models, name = '1'):
    cnt = 1
    for model in models:
        model.save(path + "submission/last/weight/" + name + '-{}.h5'.format(cnt))
        cnt +=1

# %%
first_result = train_model(first_model, r_seed = 2020, seed_ = 25)
# Out:
# epoch 0 - train_accuracy : [0.5387624502182007] - validation_loss : [1.3308559656143188] - validation_accuracy : 0.6485623003194888
# ####best_val####
# ####best_acc####
# epoch 1 - train_accuracy : [0.6073968410491943] - validation_loss : [1.1011457443237305] - validation_accuracy : 0.6869009584664537
# ####best_val####
# ####best_acc####
# epoch 2 - train_accuracy : [0.6906116604804993] - validation_loss : [0.8630918264389038] - validation_accuracy : 0.7348242811501597
# ####best_val####
# ####best_acc####
# epoch 3 - train_accuracy : [0.7048364281654358] - validation_loss : [0.8619275689125061] - validation_accuracy : 0.7539936102236422
# ####best_val####
# ####best_acc####
# epoch 4 - train_accuracy : [0.7780938744544983] - validation_loss : [0.7325383424758911] - validation_accuracy : 0.7635782747603834
# ####best_val####
# ####best_acc####
# epoch 5 - train_accuracy : [0.7446657419204712] - validation_loss : [0.7167854309082031] - validation_accuracy : 0.792332268370607
# ####best_val####
# ####best_acc####
# epoch 6 - train_accuracy : [0.808321475982666] - validation_loss : [0.6480772495269775] - validation_accuracy : 0.8083067092651757
# ####best_val####
# ####best_acc####
# epoch 7 - train_accuracy : [0.7777382731437683] - validation_loss : [0.6474367380142212] - validation_accuracy : 0.805111821086262
# ####best_val####
# epoch 8 - train_accuracy : [0.8285917639732361] - validation_loss : [0.6204175353050232] - validation_accuracy : 0.8274760383386581
# ####best_val####
# ####best_acc####
# epoch 9 - train_accuracy : [0.7962304353713989] - validation_loss : [0.6690753102302551] - validation_accuracy : 0.805111821086262
# epoch 10 - train_accuracy : [0.8492176532745361] - validation_loss : [0.6196408271789551] - validation_accuracy : 0.8242811501597445
# ####best_val####
# epoch 11 - train_accuracy : [0.8150782585144043] - validation_loss : [0.5727792978286743] - validation_accuracy : 0.8402555910543131
# ####best_val####
# ####best_acc####
# epoch 12 - train_accuracy : [0.866287350654602] - validation_loss : [0.6423032879829407] - validation_accuracy : 0.8370607028753994
# epoch 13 - train_accuracy : [0.8317922949790955] - validation_loss : [0.5996755361557007] - validation_accuracy : 0.8434504792332268
# ####best_acc####
# epoch 14 - train_accuracy : [0.8701991438865662] - validation_loss : [0.583719789981842] - validation_accuracy : 0.8338658146964856
# epoch 15 - train_accuracy : [0.8328591585159302] - validation_loss : [0.5918641090393066] - validation_accuracy : 0.8434504792332268
# ####best_acc####
# epoch 16 - train_accuracy : [0.9064722657203674] - validation_loss : [0.5073340535163879] - validation_accuracy : 0.8562300319488818
# ####best_val####
# ####best_acc####
# epoch 17 - train_accuracy : [0.8869132399559021] - validation_loss : [0.5069754123687744] - validation_accuracy : 0.8690095846645367
# ####best_val####
# ####best_acc####
# epoch 18 - train_accuracy : [0.925320029258728] - validation_loss : [0.5011908411979675] - validation_accuracy : 0.8690095846645367
# ####best_val####
# ####best_acc####
# epoch 19 - train_accuracy : [0.8954480886459351] - validation_loss : [0.5110334157943726] - validation_accuracy : 0.8626198083067093
# epoch 20 - train_accuracy : [0.9285206198692322] - validation_loss : [0.4982951581478119] - validation_accuracy : 0.8690095846645367
# ####best_val####
# ####best_acc####
# epoch 21 - train_accuracy : [0.8982930183410645] - validation_loss : [0.5163364410400391] - validation_accuracy : 0.8722044728434505
# ####best_acc####
# epoch 22 - train_accuracy : [0.933854877948761] - validation_loss : [0.50887131690979] - validation_accuracy : 0.8785942492012779
# ####best_acc####
# epoch 23 - train_accuracy : [0.9096728563308716] - validation_loss : [0.5335476994514465] - validation_accuracy : 0.8690095846645367
# epoch 24 - train_accuracy : [0.9431009888648987] - validation_loss : [0.5252021551132202] - validation_accuracy : 0.8753993610223643
# epoch 25 - train_accuracy : [0.9022048115730286] - validation_loss : [0.5223216414451599] - validation_accuracy : 0.8690095846645367
# epoch 26 - train_accuracy : [0.9441678524017334] - validation_loss : [0.5054011940956116] - validation_accuracy : 0.8849840255591054
# ####best_acc####
# epoch 27 - train_accuracy : [0.912517786026001] - validation_loss : [0.504169762134552] - validation_accuracy : 0.8722044728434505
# epoch 28 - train_accuracy : [0.9463015794754028] - validation_loss : [0.5220377445220947] - validation_accuracy : 0.8849840255591054
# ####best_acc####
# epoch 29 - train_accuracy : [0.9157183766365051] - validation_loss : [0.5223764777183533] - validation_accuracy : 0.8753993610223643
# epoch 30 - train_accuracy : [0.9519914388656616] - validation_loss : [0.5285327434539795] - validation_accuracy : 0.8722044728434505
# epoch 31 - train_accuracy : [0.9096728563308716] - validation_loss : [0.5286223888397217] - validation_accuracy : 0.8817891373801917
# epoch 32 - train_accuracy : [0.9576813578605652] - validation_loss : [0.5299268960952759] - validation_accuracy : 0.8785942492012779
# epoch 33 - train_accuracy : [0.9238975644111633] - validation_loss : [0.5164191722869873] - validation_accuracy : 0.8785942492012779
# epoch 34 - train_accuracy : [0.9615931510925293] - validation_loss : [0.5184066891670227] - validation_accuracy : 0.8785942492012779
# epoch 35 - train_accuracy : [0.925320029258728] - validation_loss : [0.5144920349121094] - validation_accuracy : 0.8753993610223643
# epoch 36 - train_accuracy : [0.9569701552391052] - validation_loss : [0.5224738121032715] - validation_accuracy : 0.8753993610223643
# epoch 37 - train_accuracy : [0.9246088266372681] - validation_loss : [0.5279591083526611] - validation_accuracy : 0.8722044728434505
# epoch 38 - train_accuracy : [0.9580369591712952] - validation_loss : [0.5274024605751038] - validation_accuracy : 0.8722044728434505
# epoch 39 - train_accuracy : [0.9317212104797363] - validation_loss : [0.514042317867279] - validation_accuracy : 0.8722044728434505
# ####################################################### cycle 0 is done
# epoch 0 - train_accuracy : [0.5430298447608948] - validation_loss : [1.4603486061096191] - validation_accuracy : 0.6230031948881789
# ####best_val####
# ####best_acc####
# epoch 1 - train_accuracy : [0.6180654168128967] - validation_loss : [1.2254679203033447] - validation_accuracy : 0.6964856230031949
# ####best_val####
# ####best_acc####
# epoch 2 - train_accuracy : [0.704480767250061] - validation_loss : [1.053710699081421] - validation_accuracy : 0.731629392971246
# ####best_val####
# ####best_acc####
# epoch 3 - train_accuracy : [0.6945234537124634] - validation_loss : [0.9365004301071167] - validation_accuracy : 0.7412140575079872
# ####best_val####
# ####best_acc####
# epoch 4 - train_accuracy : [0.7720483541488647] - validation_loss : [0.8569602370262146] - validation_accuracy : 0.7731629392971247
# ####best_val####
# ####best_acc####
# epoch 5 - train_accuracy : [0.7532005906105042] - validation_loss : [0.7134811282157898] - validation_accuracy : 0.7859424920127795
# ####best_val####
# ####best_acc####
# epoch 6 - train_accuracy : [0.8054765462875366] - validation_loss : [0.7512936592102051] - validation_accuracy : 0.805111821086262
# ####best_acc####
# epoch 7 - train_accuracy : [0.778805136680603] - validation_loss : [0.6794402599334717] - validation_accuracy : 0.805111821086262
# ####best_val####
# ####best_acc####
# epoch 8 - train_accuracy : [0.8321479558944702] - validation_loss : [0.6862359046936035] - validation_accuracy : 0.8083067092651757
# ####best_acc####
# epoch 9 - train_accuracy : [0.8054765462875366] - validation_loss : [0.6678034663200378] - validation_accuracy : 0.8115015974440895
# ####best_val####
# ####best_acc####
# epoch 10 - train_accuracy : [0.8442389965057373] - validation_loss : [0.5682471990585327] - validation_accuracy : 0.8306709265175719
# ####best_val####
# ####best_acc####
# epoch 11 - train_accuracy : [0.8143669962882996] - validation_loss : [0.6018289923667908] - validation_accuracy : 0.8242811501597445
# epoch 12 - train_accuracy : [0.8563300371170044] - validation_loss : [0.5653029084205627] - validation_accuracy : 0.853035143769968
# ####best_val####
# ####best_acc####
# epoch 13 - train_accuracy : [0.8303698301315308] - validation_loss : [0.5677493810653687] - validation_accuracy : 0.8402555910543131
# epoch 14 - train_accuracy : [0.8716216087341309] - validation_loss : [0.5495775938034058] - validation_accuracy : 0.853035143769968
# ####best_val####
# ####best_acc####
# epoch 15 - train_accuracy : [0.8485063910484314] - validation_loss : [0.5695241093635559] - validation_accuracy : 0.8242811501597445
# epoch 16 - train_accuracy : [0.8993598818778992] - validation_loss : [0.47533851861953735] - validation_accuracy : 0.8498402555910544
# ####best_val####
# epoch 17 - train_accuracy : [0.8879801034927368] - validation_loss : [0.48968490958213806] - validation_accuracy : 0.8498402555910544
# epoch 18 - train_accuracy : [0.924964427947998] - validation_loss : [0.44505438208580017] - validation_accuracy : 0.8594249201277955
# ####best_val####
# ####best_acc####
# epoch 19 - train_accuracy : [0.891536295413971] - validation_loss : [0.4701521098613739] - validation_accuracy : 0.8594249201277955
# ####best_acc####
# epoch 20 - train_accuracy : [0.9235419631004333] - validation_loss : [0.4507421851158142] - validation_accuracy : 0.8594249201277955
# ####best_acc####
# epoch 21 - train_accuracy : [0.895803689956665] - validation_loss : [0.47986575961112976] - validation_accuracy : 0.8562300319488818
# epoch 22 - train_accuracy : [0.9317212104797363] - validation_loss : [0.45966657996177673] - validation_accuracy : 0.8626198083067093
# ####best_acc####
# epoch 23 - train_accuracy : [0.8950924873352051] - validation_loss : [0.4637902081012726] - validation_accuracy : 0.865814696485623
# ####best_acc####
# epoch 24 - train_accuracy : [0.9288762211799622] - validation_loss : [0.45640289783477783] - validation_accuracy : 0.8562300319488818
# epoch 25 - train_accuracy : [0.9096728563308716] - validation_loss : [0.4665798842906952] - validation_accuracy : 0.853035143769968
# epoch 26 - train_accuracy : [0.9366998672485352] - validation_loss : [0.4393250048160553] - validation_accuracy : 0.8594249201277955
# ####best_val####
# epoch 27 - train_accuracy : [0.9096728563308716] - validation_loss : [0.4654708206653595] - validation_accuracy : 0.8562300319488818
# epoch 28 - train_accuracy : [0.9455903172492981] - validation_loss : [0.4335622489452362] - validation_accuracy : 0.8785942492012779
# ####best_val####
# ####best_acc####
# epoch 29 - train_accuracy : [0.9110953211784363] - validation_loss : [0.45790696144104004] - validation_accuracy : 0.8626198083067093
# epoch 30 - train_accuracy : [0.9452347159385681] - validation_loss : [0.45026955008506775] - validation_accuracy : 0.865814696485623
# epoch 31 - train_accuracy : [0.9210526347160339] - validation_loss : [0.45077192783355713] - validation_accuracy : 0.865814696485623
# epoch 32 - train_accuracy : [0.9530583024024963] - validation_loss : [0.4435126483440399] - validation_accuracy : 0.865814696485623
# epoch 33 - train_accuracy : [0.9160739779472351] - validation_loss : [0.4601566195487976] - validation_accuracy : 0.8626198083067093
# epoch 34 - train_accuracy : [0.9548364281654358] - validation_loss : [0.4487972557544708] - validation_accuracy : 0.8594249201277955
# epoch 35 - train_accuracy : [0.9203413724899292] - validation_loss : [0.4606970548629761] - validation_accuracy : 0.8562300319488818
# epoch 36 - train_accuracy : [0.9580369591712952] - validation_loss : [0.43668344616889954] - validation_accuracy : 0.8594249201277955
# epoch 37 - train_accuracy : [0.924964427947998] - validation_loss : [0.45735764503479004] - validation_accuracy : 0.8594249201277955
# epoch 38 - train_accuracy : [0.9566144943237305] - validation_loss : [0.43653714656829834] - validation_accuracy : 0.865814696485623
# epoch 39 - train_accuracy : [0.9370554685592651] - validation_loss : [0.451023131608963] - validation_accuracy : 0.8690095846645367
# ####################################################### cycle 1 is done
# epoch 0 - train_accuracy : [0.5469416975975037] - validation_loss : [1.399803638458252] - validation_accuracy : 0.6261980830670927
# ####best_val####
# ####best_acc####
# epoch 1 - train_accuracy : [0.6130867600440979] - validation_loss : [1.0944205522537231] - validation_accuracy : 0.6645367412140575
# ####best_val####
# ####best_acc####
# epoch 2 - train_accuracy : [0.7030583024024963] - validation_loss : [0.8404244780540466] - validation_accuracy : 0.7476038338658147
# ####best_val####
# ####best_acc####
# epoch 3 - train_accuracy : [0.7098150849342346] - validation_loss : [0.7782875895500183] - validation_accuracy : 0.7539936102236422
# ####best_val####
# ####best_acc####
# epoch 4 - train_accuracy : [0.7642247676849365] - validation_loss : [0.6942030191421509] - validation_accuracy : 0.7763578274760383
# ####best_val####
# ####best_acc####
# epoch 5 - train_accuracy : [0.7464438080787659] - validation_loss : [0.7214012145996094] - validation_accuracy : 0.7731629392971247
# epoch 6 - train_accuracy : [0.8104552030563354] - validation_loss : [0.618983805179596] - validation_accuracy : 0.805111821086262
# ####best_val####
# ####best_acc####
# epoch 7 - train_accuracy : [0.7763158082962036] - validation_loss : [0.6482253074645996] - validation_accuracy : 0.7891373801916933
# epoch 8 - train_accuracy : [0.8204125165939331] - validation_loss : [0.5789215564727783] - validation_accuracy : 0.8178913738019169
# ####best_val####
# ####best_acc####
# epoch 9 - train_accuracy : [0.7997866272926331] - validation_loss : [0.5985752940177917] - validation_accuracy : 0.7955271565495208
# epoch 10 - train_accuracy : [0.8438833355903625] - validation_loss : [0.5468449592590332] - validation_accuracy : 0.8370607028753994
# ####best_val####
# ####best_acc####
# epoch 11 - train_accuracy : [0.8182787895202637] - validation_loss : [0.5484752058982849] - validation_accuracy : 0.853035143769968
# ####best_acc####
# epoch 12 - train_accuracy : [0.8534850478172302] - validation_loss : [0.5529107451438904] - validation_accuracy : 0.8306709265175719
# epoch 13 - train_accuracy : [0.8357041478157043] - validation_loss : [0.5486546158790588] - validation_accuracy : 0.8306709265175719
# epoch 14 - train_accuracy : [0.8677098155021667] - validation_loss : [0.534135103225708] - validation_accuracy : 0.8434504792332268
# ####best_val####
# epoch 15 - train_accuracy : [0.8417496681213379] - validation_loss : [0.5601587891578674] - validation_accuracy : 0.8274760383386581
# epoch 16 - train_accuracy : [0.9022048115730286] - validation_loss : [0.49287331104278564] - validation_accuracy : 0.8466453674121406
# ####best_val####
# epoch 17 - train_accuracy : [0.8897581696510315] - validation_loss : [0.47939199209213257] - validation_accuracy : 0.865814696485623
# ####best_val####
# ####best_acc####
# epoch 18 - train_accuracy : [0.9242532253265381] - validation_loss : [0.4488382637500763] - validation_accuracy : 0.8562300319488818
# ####best_val####
# epoch 19 - train_accuracy : [0.8904694318771362] - validation_loss : [0.49119699001312256] - validation_accuracy : 0.8562300319488818
# epoch 20 - train_accuracy : [0.9214082360267639] - validation_loss : [0.4759032428264618] - validation_accuracy : 0.853035143769968
# epoch 21 - train_accuracy : [0.9007823467254639] - validation_loss : [0.4881993532180786] - validation_accuracy : 0.853035143769968
# epoch 22 - train_accuracy : [0.9299430847167969] - validation_loss : [0.47002360224723816] - validation_accuracy : 0.8498402555910544
# epoch 23 - train_accuracy : [0.9061166644096375] - validation_loss : [0.46142691373825073] - validation_accuracy : 0.8626198083067093
# epoch 24 - train_accuracy : [0.9409672617912292] - validation_loss : [0.4735243320465088] - validation_accuracy : 0.853035143769968
# epoch 25 - train_accuracy : [0.9146515130996704] - validation_loss : [0.49547111988067627] - validation_accuracy : 0.8498402555910544
# epoch 26 - train_accuracy : [0.9366998672485352] - validation_loss : [0.4610808193683624] - validation_accuracy : 0.8562300319488818
# epoch 27 - train_accuracy : [0.9146515130996704] - validation_loss : [0.49864518642425537] - validation_accuracy : 0.8498402555910544
# epoch 28 - train_accuracy : [0.9402560591697693] - validation_loss : [0.4733958840370178] - validation_accuracy : 0.8690095846645367
# ####best_acc####
# epoch 29 - train_accuracy : [0.9135846495628357] - validation_loss : [0.4934885799884796] - validation_accuracy : 0.853035143769968
# epoch 30 - train_accuracy : [0.9487909078598022] - validation_loss : [0.540725827217102] - validation_accuracy : 0.8498402555910544
# epoch 31 - train_accuracy : [0.9185633063316345] - validation_loss : [0.5058185458183289] - validation_accuracy : 0.853035143769968
# epoch 32 - train_accuracy : [0.9523470997810364] - validation_loss : [0.4952397346496582] - validation_accuracy : 0.853035143769968
# epoch 33 - train_accuracy : [0.924964427947998] - validation_loss : [0.4898090660572052] - validation_accuracy : 0.853035143769968
# epoch 34 - train_accuracy : [0.9551920294761658] - validation_loss : [0.49174582958221436] - validation_accuracy : 0.853035143769968
# epoch 35 - train_accuracy : [0.9320768117904663] - validation_loss : [0.5097303986549377] - validation_accuracy : 0.8498402555910544
# epoch 36 - train_accuracy : [0.9583926200866699] - validation_loss : [0.4930332601070404] - validation_accuracy : 0.853035143769968
# epoch 37 - train_accuracy : [0.9292318820953369] - validation_loss : [0.5016235709190369] - validation_accuracy : 0.853035143769968
# epoch 38 - train_accuracy : [0.954125165939331] - validation_loss : [0.5059186220169067] - validation_accuracy : 0.853035143769968
# epoch 39 - train_accuracy : [0.9356330037117004] - validation_loss : [0.4960853159427643] - validation_accuracy : 0.8498402555910544
# ####################################################### cycle 2 is done
# epoch 0 - train_accuracy : [0.5487197637557983] - validation_loss : [1.3462879657745361] - validation_accuracy : 0.6389776357827476
# ####best_val####
# ####best_acc####
# epoch 1 - train_accuracy : [0.6116642951965332] - validation_loss : [1.0795574188232422] - validation_accuracy : 0.6677316293929713
# ####best_val####
# ####best_acc####
# epoch 2 - train_accuracy : [0.6895447969436646] - validation_loss : [0.8221872448921204] - validation_accuracy : 0.7348242811501597
# ####best_val####
# ####best_acc####
# epoch 3 - train_accuracy : [0.7005689740180969] - validation_loss : [0.8368159532546997] - validation_accuracy : 0.7507987220447284
# ####best_acc####
# epoch 4 - train_accuracy : [0.7631579041481018] - validation_loss : [0.648490309715271] - validation_accuracy : 0.7763578274760383
# ####best_val####
# ####best_acc####
# epoch 5 - train_accuracy : [0.7379089593887329] - validation_loss : [0.6495450139045715] - validation_accuracy : 0.792332268370607
# ####best_acc####
# epoch 6 - train_accuracy : [0.7930298447608948] - validation_loss : [0.6239239573478699] - validation_accuracy : 0.7827476038338658
# ####best_val####
# epoch 7 - train_accuracy : [0.7713371515274048] - validation_loss : [0.6339403986930847] - validation_accuracy : 0.7859424920127795
# epoch 8 - train_accuracy : [0.8197012543678284] - validation_loss : [0.572031557559967] - validation_accuracy : 0.8146964856230032
# ####best_val####
# ####best_acc####
# epoch 9 - train_accuracy : [0.7869843244552612] - validation_loss : [0.5273401737213135] - validation_accuracy : 0.8274760383386581
# ####best_val####
# ####best_acc####
# epoch 10 - train_accuracy : [0.8403271436691284] - validation_loss : [0.5532697439193726] - validation_accuracy : 0.8178913738019169
# epoch 11 - train_accuracy : [0.8058321475982666] - validation_loss : [0.5525521039962769] - validation_accuracy : 0.8178913738019169
# epoch 12 - train_accuracy : [0.8549075126647949] - validation_loss : [0.5023703575134277] - validation_accuracy : 0.8338658146964856
# ####best_val####
# ####best_acc####
# epoch 13 - train_accuracy : [0.8257467746734619] - validation_loss : [0.5136238932609558] - validation_accuracy : 0.8274760383386581
# epoch 14 - train_accuracy : [0.8659317493438721] - validation_loss : [0.5032010078430176] - validation_accuracy : 0.8370607028753994
# ####best_acc####
# epoch 15 - train_accuracy : [0.8367709517478943] - validation_loss : [0.5745663642883301] - validation_accuracy : 0.8242811501597445
# epoch 16 - train_accuracy : [0.9100284576416016] - validation_loss : [0.4564860761165619] - validation_accuracy : 0.865814696485623
# ####best_val####
# ####best_acc####
# epoch 17 - train_accuracy : [0.8883357048034668] - validation_loss : [0.4580064117908478] - validation_accuracy : 0.865814696485623
# ####best_acc####
# epoch 18 - train_accuracy : [0.9196301698684692] - validation_loss : [0.4517323970794678] - validation_accuracy : 0.8626198083067093
# ####best_val####
# epoch 19 - train_accuracy : [0.8929587602615356] - validation_loss : [0.47028839588165283] - validation_accuracy : 0.8562300319488818
# epoch 20 - train_accuracy : [0.9320768117904663] - validation_loss : [0.4702751040458679] - validation_accuracy : 0.8498402555910544
# epoch 21 - train_accuracy : [0.8968705534934998] - validation_loss : [0.47558945417404175] - validation_accuracy : 0.8562300319488818
# epoch 22 - train_accuracy : [0.933499276638031] - validation_loss : [0.46167972683906555] - validation_accuracy : 0.8466453674121406
# epoch 23 - train_accuracy : [0.9054054021835327] - validation_loss : [0.4808294177055359] - validation_accuracy : 0.8594249201277955
# epoch 24 - train_accuracy : [0.9384779334068298] - validation_loss : [0.4573533833026886] - validation_accuracy : 0.8690095846645367
# ####best_acc####
# epoch 25 - train_accuracy : [0.8986486196517944] - validation_loss : [0.45524996519088745] - validation_accuracy : 0.865814696485623
# epoch 26 - train_accuracy : [0.9406116604804993] - validation_loss : [0.4697466492652893] - validation_accuracy : 0.865814696485623
# epoch 27 - train_accuracy : [0.9118065237998962] - validation_loss : [0.4840048849582672] - validation_accuracy : 0.8594249201277955
# epoch 28 - train_accuracy : [0.9399003982543945] - validation_loss : [0.47176074981689453] - validation_accuracy : 0.865814696485623
# epoch 29 - train_accuracy : [0.912162184715271] - validation_loss : [0.485105961561203] - validation_accuracy : 0.8690095846645367
# ####best_acc####
# epoch 30 - train_accuracy : [0.9470127820968628] - validation_loss : [0.4760880768299103] - validation_accuracy : 0.8722044728434505
# ####best_acc####
# epoch 31 - train_accuracy : [0.9214082360267639] - validation_loss : [0.4626700282096863] - validation_accuracy : 0.8690095846645367
# epoch 32 - train_accuracy : [0.9576813578605652] - validation_loss : [0.4540811777114868] - validation_accuracy : 0.8722044728434505
# ####best_acc####
# epoch 33 - train_accuracy : [0.9160739779472351] - validation_loss : [0.4406164586544037] - validation_accuracy : 0.8785942492012779
# ####best_val####
# ####best_acc####
# epoch 34 - train_accuracy : [0.9551920294761658] - validation_loss : [0.45409414172172546] - validation_accuracy : 0.8722044728434505
# epoch 35 - train_accuracy : [0.9246088266372681] - validation_loss : [0.4524213373661041] - validation_accuracy : 0.8753993610223643
# epoch 36 - train_accuracy : [0.9559032917022705] - validation_loss : [0.44530782103538513] - validation_accuracy : 0.8785942492012779
# ####best_acc####
# epoch 37 - train_accuracy : [0.9292318820953369] - validation_loss : [0.44292375445365906] - validation_accuracy : 0.8690095846645367
# epoch 38 - train_accuracy : [0.9555476307868958] - validation_loss : [0.4484129250049591] - validation_accuracy : 0.8690095846645367
# epoch 39 - train_accuracy : [0.932788074016571] - validation_loss : [0.444667249917984] - validation_accuracy : 0.8785942492012779
# ####best_acc####
# ####################################################### cycle 3 is done
# epoch 0 - train_accuracy : [0.5472972989082336] - validation_loss : [1.5962291955947876] - validation_accuracy : 0.6038338658146964
# ####best_val####
# ####best_acc####
# epoch 1 - train_accuracy : [0.6059743762016296] - validation_loss : [1.2452759742736816] - validation_accuracy : 0.6517571884984026
# ####best_val####
# ####best_acc####
# epoch 2 - train_accuracy : [0.704480767250061] - validation_loss : [1.0543360710144043] - validation_accuracy : 0.6996805111821086
# ####best_val####
# ####best_acc####
# epoch 3 - train_accuracy : [0.6980796456336975] - validation_loss : [0.9862974882125854] - validation_accuracy : 0.7252396166134185
# ####best_val####
# ####best_acc####
# epoch 4 - train_accuracy : [0.7596017122268677] - validation_loss : [0.8849270939826965] - validation_accuracy : 0.7699680511182109
# ####best_val####
# ####best_acc####
# epoch 5 - train_accuracy : [0.7482219338417053] - validation_loss : [0.8363078236579895] - validation_accuracy : 0.744408945686901
# ####best_val####
# epoch 6 - train_accuracy : [0.7980085611343384] - validation_loss : [0.7492433190345764] - validation_accuracy : 0.792332268370607
# ####best_val####
# ####best_acc####
# epoch 7 - train_accuracy : [0.7756045460700989] - validation_loss : [0.7799031138420105] - validation_accuracy : 0.7667731629392971
# epoch 8 - train_accuracy : [0.8261024355888367] - validation_loss : [0.6835778951644897] - validation_accuracy : 0.8146964856230032
# ####best_val####
# ####best_acc####
# epoch 9 - train_accuracy : [0.7937411069869995] - validation_loss : [0.6809207797050476] - validation_accuracy : 0.8115015974440895
# ####best_val####
# epoch 10 - train_accuracy : [0.8406828045845032] - validation_loss : [0.655261754989624] - validation_accuracy : 0.805111821086262
# ####best_val####
# epoch 11 - train_accuracy : [0.8157894611358643] - validation_loss : [0.6972404718399048] - validation_accuracy : 0.8083067092651757
# epoch 12 - train_accuracy : [0.8595305681228638] - validation_loss : [0.6179769039154053] - validation_accuracy : 0.8210862619808307
# ####best_val####
# ####best_acc####
# epoch 13 - train_accuracy : [0.8275249004364014] - validation_loss : [0.6056210994720459] - validation_accuracy : 0.8306709265175719
# ####best_val####
# ####best_acc####
# epoch 14 - train_accuracy : [0.8741109371185303] - validation_loss : [0.6024062633514404] - validation_accuracy : 0.8242811501597445
# ####best_val####
# epoch 15 - train_accuracy : [0.846372663974762] - validation_loss : [0.6127810478210449] - validation_accuracy : 0.8242811501597445
# epoch 16 - train_accuracy : [0.9018492102622986] - validation_loss : [0.4991370737552643] - validation_accuracy : 0.8626198083067093
# ####best_val####
# ####best_acc####
# epoch 17 - train_accuracy : [0.8869132399559021] - validation_loss : [0.5032860040664673] - validation_accuracy : 0.865814696485623
# ####best_acc####
# epoch 18 - train_accuracy : [0.9160739779472351] - validation_loss : [0.506019115447998] - validation_accuracy : 0.8594249201277955
# epoch 19 - train_accuracy : [0.8918918967247009] - validation_loss : [0.48086702823638916] - validation_accuracy : 0.8722044728434505
# ####best_val####
# ####best_acc####
# epoch 20 - train_accuracy : [0.9231863617897034] - validation_loss : [0.49812430143356323] - validation_accuracy : 0.8594249201277955
# epoch 21 - train_accuracy : [0.8950924873352051] - validation_loss : [0.5044535398483276] - validation_accuracy : 0.8498402555910544
# epoch 22 - train_accuracy : [0.9256756901741028] - validation_loss : [0.48822322487831116] - validation_accuracy : 0.8594249201277955
# epoch 23 - train_accuracy : [0.8933143615722656] - validation_loss : [0.501022219657898] - validation_accuracy : 0.8594249201277955
# epoch 24 - train_accuracy : [0.9310099482536316] - validation_loss : [0.4846055805683136] - validation_accuracy : 0.8594249201277955
# epoch 25 - train_accuracy : [0.9096728563308716] - validation_loss : [0.4808073341846466] - validation_accuracy : 0.8626198083067093
# ####best_val####
# epoch 26 - train_accuracy : [0.9366998672485352] - validation_loss : [0.4983808994293213] - validation_accuracy : 0.8690095846645367
# epoch 27 - train_accuracy : [0.9071835279464722] - validation_loss : [0.5268819332122803] - validation_accuracy : 0.8722044728434505
# ####best_acc####
# epoch 28 - train_accuracy : [0.9313655495643616] - validation_loss : [0.5049115419387817] - validation_accuracy : 0.8722044728434505
# ####best_acc####
# epoch 29 - train_accuracy : [0.9139402508735657] - validation_loss : [0.5115144848823547] - validation_accuracy : 0.8562300319488818
# epoch 30 - train_accuracy : [0.9473684430122375] - validation_loss : [0.5108810663223267] - validation_accuracy : 0.8722044728434505
# ####best_acc####
# epoch 31 - train_accuracy : [0.9107396602630615] - validation_loss : [0.4914223253726959] - validation_accuracy : 0.8753993610223643
# ####best_acc####
# epoch 32 - train_accuracy : [0.9495021104812622] - validation_loss : [0.49747854471206665] - validation_accuracy : 0.8785942492012779
# ####best_acc####
# epoch 33 - train_accuracy : [0.9214082360267639] - validation_loss : [0.5046577453613281] - validation_accuracy : 0.8594249201277955
# epoch 34 - train_accuracy : [0.9477240443229675] - validation_loss : [0.5023810267448425] - validation_accuracy : 0.8722044728434505
# epoch 35 - train_accuracy : [0.9285206198692322] - validation_loss : [0.504951536655426] - validation_accuracy : 0.8626198083067093
# epoch 36 - train_accuracy : [0.9548364281654358] - validation_loss : [0.5003032684326172] - validation_accuracy : 0.8722044728434505
# epoch 37 - train_accuracy : [0.9263868927955627] - validation_loss : [0.5050965547561646] - validation_accuracy : 0.865814696485623
# epoch 38 - train_accuracy : [0.9555476307868958] - validation_loss : [0.511631429195404] - validation_accuracy : 0.865814696485623
# epoch 39 - train_accuracy : [0.9278094172477722] - validation_loss : [0.507102906703949] - validation_accuracy : 0.8690095846645367
# ####################################################### cycle 4 is done
# epoch 0 - train_accuracy : [0.5357269644737244] - validation_loss : [1.5965360403060913] - validation_accuracy : 0.5961538461538461
# ####best_val####
# ####best_acc####
# epoch 1 - train_accuracy : [0.5968716740608215] - validation_loss : [1.1550816297531128] - validation_accuracy : 0.6794871794871795
# ####best_val####
# ####best_acc####
# epoch 2 - train_accuracy : [0.6992534399032593] - validation_loss : [0.9492627382278442] - validation_accuracy : 0.7403846153846154
# ####best_val####
# ####best_acc####
# epoch 3 - train_accuracy : [0.6924991011619568] - validation_loss : [0.9678694605827332] - validation_accuracy : 0.7211538461538461
# epoch 4 - train_accuracy : [0.7614646553993225] - validation_loss : [0.8468632698059082] - validation_accuracy : 0.7692307692307693
# ####best_val####
# ####best_acc####
# epoch 5 - train_accuracy : [0.7394241094589233] - validation_loss : [0.7721690535545349] - validation_accuracy : 0.7692307692307693
# ####best_val####
# ####best_acc####
# epoch 6 - train_accuracy : [0.7977248430252075] - validation_loss : [0.7270239591598511] - validation_accuracy : 0.7980769230769231
# ####best_val####
# ####best_acc####
# epoch 7 - train_accuracy : [0.7785282731056213] - validation_loss : [0.753331184387207] - validation_accuracy : 0.7852564102564102
# epoch 8 - train_accuracy : [0.8279417157173157] - validation_loss : [0.6867148280143738] - validation_accuracy : 0.8141025641025641
# ####best_val####
# ####best_acc####
# epoch 9 - train_accuracy : [0.8005687594413757] - validation_loss : [0.7380980253219604] - validation_accuracy : 0.8044871794871795
# epoch 10 - train_accuracy : [0.8368290066719055] - validation_loss : [0.6650530695915222] - validation_accuracy : 0.8173076923076923
# ####best_val####
# ####best_acc####
# epoch 11 - train_accuracy : [0.8197653889656067] - validation_loss : [0.6940690875053406] - validation_accuracy : 0.8108974358974359
# epoch 12 - train_accuracy : [0.861002504825592] - validation_loss : [0.693533182144165] - validation_accuracy : 0.8108974358974359
# epoch 13 - train_accuracy : [0.8258087635040283] - validation_loss : [0.7382563352584839] - validation_accuracy : 0.8012820512820513
# epoch 14 - train_accuracy : [0.8748666644096375] - validation_loss : [0.6916088461875916] - validation_accuracy : 0.8141025641025641
# epoch 15 - train_accuracy : [0.835407018661499] - validation_loss : [0.6707429885864258] - validation_accuracy : 0.8397435897435898
# ####best_acc####
# epoch 16 - train_accuracy : [0.9004621505737305] - validation_loss : [0.5870747566223145] - validation_accuracy : 0.8525641025641025
# ####best_val####
# ####best_acc####
# epoch 17 - train_accuracy : [0.8862424492835999] - validation_loss : [0.5728176236152649] - validation_accuracy : 0.8557692307692307
# ####best_val####
# ####best_acc####
# epoch 18 - train_accuracy : [0.9274795651435852] - validation_loss : [0.5678603053092957] - validation_accuracy : 0.8621794871794872
# ####best_val####
# ####best_acc####
# epoch 19 - train_accuracy : [0.9029505848884583] - validation_loss : [0.5922911167144775] - validation_accuracy : 0.8557692307692307
# epoch 20 - train_accuracy : [0.9242801070213318] - validation_loss : [0.582727313041687] - validation_accuracy : 0.8493589743589743
# epoch 21 - train_accuracy : [0.9057945013046265] - validation_loss : [0.6028604507446289] - validation_accuracy : 0.8525641025641025
# epoch 22 - train_accuracy : [0.9349449276924133] - validation_loss : [0.5830349326133728] - validation_accuracy : 0.8557692307692307
# epoch 23 - train_accuracy : [0.9093494415283203] - validation_loss : [0.6007713675498962] - validation_accuracy : 0.8525641025641025
# epoch 24 - train_accuracy : [0.9335229396820068] - validation_loss : [0.6003692746162415] - validation_accuracy : 0.8589743589743589
# epoch 25 - train_accuracy : [0.9104159474372864] - validation_loss : [0.602681040763855] - validation_accuracy : 0.8525641025641025
# epoch 26 - train_accuracy : [0.9416992664337158] - validation_loss : [0.5968579053878784] - validation_accuracy : 0.8525641025641025
# epoch 27 - train_accuracy : [0.9100604057312012] - validation_loss : [0.6172176003456116] - validation_accuracy : 0.8525641025641025
# epoch 28 - train_accuracy : [0.9452542066574097] - validation_loss : [0.5955392122268677] - validation_accuracy : 0.8493589743589743
# epoch 29 - train_accuracy : [0.9139708280563354] - validation_loss : [0.6147944331169128] - validation_accuracy : 0.842948717948718
# epoch 30 - train_accuracy : [0.9441877007484436] - validation_loss : [0.6137450933456421] - validation_accuracy : 0.8493589743589743
# epoch 31 - train_accuracy : [0.9228581786155701] - validation_loss : [0.6217476725578308] - validation_accuracy : 0.8461538461538461
# epoch 32 - train_accuracy : [0.952719509601593] - validation_loss : [0.6266776323318481] - validation_accuracy : 0.8621794871794872
# ####best_acc####
# epoch 33 - train_accuracy : [0.9328119158744812] - validation_loss : [0.6255799531936646] - validation_accuracy : 0.8557692307692307
# epoch 34 - train_accuracy : [0.9573408961296082] - validation_loss : [0.6309716105461121] - validation_accuracy : 0.8557692307692307
# epoch 35 - train_accuracy : [0.9285460114479065] - validation_loss : [0.6190241575241089] - validation_accuracy : 0.8557692307692307
# epoch 36 - train_accuracy : [0.9552079439163208] - validation_loss : [0.6229020357131958] - validation_accuracy : 0.8493589743589743
# epoch 37 - train_accuracy : [0.9235691428184509] - validation_loss : [0.6299228072166443] - validation_accuracy : 0.8493589743589743
# epoch 38 - train_accuracy : [0.9548524618148804] - validation_loss : [0.6310837864875793] - validation_accuracy : 0.8525641025641025
# epoch 39 - train_accuracy : [0.931034505367279] - validation_loss : [0.6329742074012756] - validation_accuracy : 0.8461538461538461
# ####################################################### cycle 5 is done
# epoch 0 - train_accuracy : [0.5424813628196716] - validation_loss : [1.4241275787353516] - validation_accuracy : 0.6217948717948718
# ####best_val####
# ####best_acc####
# epoch 1 - train_accuracy : [0.6157127618789673] - validation_loss : [1.3567512035369873] - validation_accuracy : 0.6474358974358975
# ####best_val####
# ####best_acc####
# epoch 2 - train_accuracy : [0.6978315114974976] - validation_loss : [1.0610135793685913] - validation_accuracy : 0.7051282051282052
# ####best_val####
# ####best_acc####
# epoch 3 - train_accuracy : [0.7060078382492065] - validation_loss : [0.9993231296539307] - validation_accuracy : 0.7403846153846154
# ####best_val####
# ####best_acc####
# epoch 4 - train_accuracy : [0.7671524882316589] - validation_loss : [0.9461155533790588] - validation_accuracy : 0.75
# ####best_val####
# ####best_acc####
# epoch 5 - train_accuracy : [0.7486668825149536] - validation_loss : [0.8949191570281982] - validation_accuracy : 0.75
# ####best_val####
# ####best_acc####
# epoch 6 - train_accuracy : [0.8012797832489014] - validation_loss : [0.9341241121292114] - validation_accuracy : 0.7628205128205128
# ####best_acc####
# epoch 7 - train_accuracy : [0.7824386954307556] - validation_loss : [0.9102967381477356] - validation_accuracy : 0.7724358974358975
# ####best_acc####
# epoch 8 - train_accuracy : [0.8275862336158752] - validation_loss : [0.8729971051216125] - validation_accuracy : 0.7756410256410257
# ####best_val####
# ####best_acc####
# epoch 9 - train_accuracy : [0.8016352653503418] - validation_loss : [0.959993302822113] - validation_accuracy : 0.7756410256410257
# ####best_acc####
# epoch 10 - train_accuracy : [0.8531816601753235] - validation_loss : [0.8571909666061401] - validation_accuracy : 0.782051282051282
# ####best_val####
# ####best_acc####
# epoch 11 - train_accuracy : [0.8165659308433533] - validation_loss : [0.9138583540916443] - validation_accuracy : 0.7756410256410257
# epoch 12 - train_accuracy : [0.8585140705108643] - validation_loss : [0.8505279421806335] - validation_accuracy : 0.7948717948717948
# ####best_val####
# ####best_acc####
# epoch 13 - train_accuracy : [0.8314965963363647] - validation_loss : [0.856296956539154] - validation_accuracy : 0.7852564102564102
# epoch 14 - train_accuracy : [0.8738002181053162] - validation_loss : [0.8288508653640747] - validation_accuracy : 0.7948717948717948
# ####best_val####
# ####best_acc####
# epoch 15 - train_accuracy : [0.8439388275146484] - validation_loss : [0.8259487748146057] - validation_accuracy : 0.8108974358974359
# ####best_val####
# ####best_acc####
# epoch 16 - train_accuracy : [0.9089939594268799] - validation_loss : [0.7631552219390869] - validation_accuracy : 0.8365384615384616
# ####best_val####
# ####best_acc####
# epoch 17 - train_accuracy : [0.8858869671821594] - validation_loss : [0.7665071487426758] - validation_accuracy : 0.8269230769230769
# epoch 18 - train_accuracy : [0.9253466129302979] - validation_loss : [0.7577892541885376] - validation_accuracy : 0.842948717948718
# ####best_val####
# ####best_acc####
# epoch 19 - train_accuracy : [0.8958407640457153] - validation_loss : [0.74661785364151] - validation_accuracy : 0.8333333333333334
# ####best_val####
# epoch 20 - train_accuracy : [0.9274795651435852] - validation_loss : [0.7719489932060242] - validation_accuracy : 0.842948717948718
# ####best_acc####
# epoch 21 - train_accuracy : [0.9050835371017456] - validation_loss : [0.7454861998558044] - validation_accuracy : 0.8365384615384616
# ####best_val####
# epoch 22 - train_accuracy : [0.9260575771331787] - validation_loss : [0.7570766806602478] - validation_accuracy : 0.8365384615384616
# epoch 23 - train_accuracy : [0.9047280550003052] - validation_loss : [0.7523435354232788] - validation_accuracy : 0.8301282051282052
# epoch 24 - train_accuracy : [0.9384998083114624] - validation_loss : [0.7812076210975647] - validation_accuracy : 0.8301282051282052
# epoch 25 - train_accuracy : [0.9171702861785889] - validation_loss : [0.7624343633651733] - validation_accuracy : 0.8365384615384616
# epoch 26 - train_accuracy : [0.9395663142204285] - validation_loss : [0.7629390358924866] - validation_accuracy : 0.8269230769230769
# epoch 27 - train_accuracy : [0.9033060669898987] - validation_loss : [0.7501804232597351] - validation_accuracy : 0.8333333333333334
# epoch 28 - train_accuracy : [0.9456096887588501] - validation_loss : [0.7755675911903381] - validation_accuracy : 0.8301282051282052
# epoch 29 - train_accuracy : [0.9189477562904358] - validation_loss : [0.7381723523139954] - validation_accuracy : 0.842948717948718
# ####best_val####
# ####best_acc####
# epoch 30 - train_accuracy : [0.9434767365455627] - validation_loss : [0.7590091824531555] - validation_accuracy : 0.842948717948718
# ####best_acc####
# epoch 31 - train_accuracy : [0.9239246249198914] - validation_loss : [0.753473162651062] - validation_accuracy : 0.8365384615384616
# epoch 32 - train_accuracy : [0.9598293900489807] - validation_loss : [0.7733173370361328] - validation_accuracy : 0.8333333333333334
# epoch 33 - train_accuracy : [0.9253466129302979] - validation_loss : [0.7385263442993164] - validation_accuracy : 0.8365384615384616
# epoch 34 - train_accuracy : [0.9569854140281677] - validation_loss : [0.7808097004890442] - validation_accuracy : 0.8365384615384616
# epoch 35 - train_accuracy : [0.9242801070213318] - validation_loss : [0.7542769312858582] - validation_accuracy : 0.8397435897435898
# epoch 36 - train_accuracy : [0.9573408961296082] - validation_loss : [0.767044186592102] - validation_accuracy : 0.842948717948718
# ####best_acc####
# epoch 37 - train_accuracy : [0.9264130592346191] - validation_loss : [0.7741894721984863] - validation_accuracy : 0.8397435897435898
# epoch 38 - train_accuracy : [0.952719509601593] - validation_loss : [0.7807520627975464] - validation_accuracy : 0.8397435897435898
# epoch 39 - train_accuracy : [0.9281905293464661] - validation_loss : [0.7683258652687073] - validation_accuracy : 0.8365384615384616
# ####################################################### cycle 6 is done
# epoch 0 - train_accuracy : [0.5467472672462463] - validation_loss : [1.6333130598068237] - validation_accuracy : 0.5833333333333334
# ####best_val####
# ####best_acc####
# epoch 1 - train_accuracy : [0.6135798096656799] - validation_loss : [1.174306035041809] - validation_accuracy : 0.6666666666666666
# ####best_val####
# ####best_acc####
# epoch 2 - train_accuracy : [0.7038748860359192] - validation_loss : [0.9051370620727539] - validation_accuracy : 0.75
# ####best_val####
# ####best_acc####
# epoch 3 - train_accuracy : [0.6985424757003784] - validation_loss : [0.9153883457183838] - validation_accuracy : 0.7307692307692307
# epoch 4 - train_accuracy : [0.765375018119812] - validation_loss : [0.726158618927002] - validation_accuracy : 0.7852564102564102
# ####best_val####
# ####best_acc####
# epoch 5 - train_accuracy : [0.7511553764343262] - validation_loss : [0.7012590765953064] - validation_accuracy : 0.7980769230769231
# ####best_val####
# ####best_acc####
# epoch 6 - train_accuracy : [0.7973693609237671] - validation_loss : [0.6204587817192078] - validation_accuracy : 0.8108974358974359
# ####best_val####
# ####best_acc####
# epoch 7 - train_accuracy : [0.7785282731056213] - validation_loss : [0.6382452845573425] - validation_accuracy : 0.8141025641025641
# ####best_acc####
# epoch 8 - train_accuracy : [0.8304301500320435] - validation_loss : [0.5713706612586975] - validation_accuracy : 0.8237179487179487
# ####best_val####
# ####best_acc####
# epoch 9 - train_accuracy : [0.798080325126648] - validation_loss : [0.6508100032806396] - validation_accuracy : 0.8301282051282052
# ####best_acc####
# epoch 10 - train_accuracy : [0.8378955125808716] - validation_loss : [0.5919449925422668] - validation_accuracy : 0.8237179487179487
# epoch 11 - train_accuracy : [0.8115890622138977] - validation_loss : [0.5932190418243408] - validation_accuracy : 0.8301282051282052
# ####best_acc####
# epoch 12 - train_accuracy : [0.8570920825004578] - validation_loss : [0.613500714302063] - validation_accuracy : 0.8237179487179487
# epoch 13 - train_accuracy : [0.823675811290741] - validation_loss : [0.5997724533081055] - validation_accuracy : 0.8237179487179487
# epoch 14 - train_accuracy : [0.8656238913536072] - validation_loss : [0.643085777759552] - validation_accuracy : 0.8269230769230769
# epoch 15 - train_accuracy : [0.8368290066719055] - validation_loss : [0.5937020778656006] - validation_accuracy : 0.8269230769230769
# epoch 16 - train_accuracy : [0.9068610072135925] - validation_loss : [0.4959310293197632] - validation_accuracy : 0.8525641025641025
# ####best_val####
# ####best_acc####
# epoch 17 - train_accuracy : [0.8887308835983276] - validation_loss : [0.47370126843452454] - validation_accuracy : 0.8653846153846154
# ####best_val####
# ####best_acc####
# epoch 18 - train_accuracy : [0.9175257682800293] - validation_loss : [0.49104490876197815] - validation_accuracy : 0.8525641025641025
# epoch 19 - train_accuracy : [0.893707811832428] - validation_loss : [0.4700073301792145] - validation_accuracy : 0.8525641025641025
# ####best_val####
# epoch 20 - train_accuracy : [0.9317454695701599] - validation_loss : [0.4780239164829254] - validation_accuracy : 0.8589743589743589
# epoch 21 - train_accuracy : [0.8901528716087341] - validation_loss : [0.48440635204315186] - validation_accuracy : 0.8557692307692307
# epoch 22 - train_accuracy : [0.9292570352554321] - validation_loss : [0.4901765286922455] - validation_accuracy : 0.8461538461538461
# epoch 23 - train_accuracy : [0.907216489315033] - validation_loss : [0.46417587995529175] - validation_accuracy : 0.8685897435897436
# ####best_val####
# ####best_acc####
# epoch 24 - train_accuracy : [0.9360113739967346] - validation_loss : [0.48437392711639404] - validation_accuracy : 0.8525641025641025
# epoch 25 - train_accuracy : [0.9036615490913391] - validation_loss : [0.45582160353660583] - validation_accuracy : 0.8493589743589743
# ####best_val####
# epoch 26 - train_accuracy : [0.9367223381996155] - validation_loss : [0.49837762117385864] - validation_accuracy : 0.8525641025641025
# epoch 27 - train_accuracy : [0.9043725728988647] - validation_loss : [0.4551299512386322] - validation_accuracy : 0.8653846153846154
# ####best_val####
# epoch 28 - train_accuracy : [0.9416992664337158] - validation_loss : [0.4775044918060303] - validation_accuracy : 0.8653846153846154
# epoch 29 - train_accuracy : [0.9175257682800293] - validation_loss : [0.4655779302120209] - validation_accuracy : 0.875
# ####best_acc####
# epoch 30 - train_accuracy : [0.9452542066574097] - validation_loss : [0.5010404586791992] - validation_accuracy : 0.8557692307692307
# epoch 31 - train_accuracy : [0.9182367324829102] - validation_loss : [0.4782465398311615] - validation_accuracy : 0.8717948717948718
# epoch 32 - train_accuracy : [0.9534304738044739] - validation_loss : [0.4866333603858948] - validation_accuracy : 0.875
# ####best_acc####
# epoch 33 - train_accuracy : [0.9185922741889954] - validation_loss : [0.4693465530872345] - validation_accuracy : 0.8685897435897436
# epoch 34 - train_accuracy : [0.9537860155105591] - validation_loss : [0.4736093282699585] - validation_accuracy : 0.8717948717948718
# epoch 35 - train_accuracy : [0.921791672706604] - validation_loss : [0.4685162305831909] - validation_accuracy : 0.8717948717948718
# epoch 36 - train_accuracy : [0.9584074020385742] - validation_loss : [0.4890834093093872] - validation_accuracy : 0.8782051282051282
# ####best_acc####
# epoch 37 - train_accuracy : [0.9221471548080444] - validation_loss : [0.46627944707870483] - validation_accuracy : 0.8685897435897436
# epoch 38 - train_accuracy : [0.9612513184547424] - validation_loss : [0.4911328852176666] - validation_accuracy : 0.8782051282051282
# ####best_acc####
# epoch 39 - train_accuracy : [0.9189477562904358] - validation_loss : [0.48460838198661804] - validation_accuracy : 0.8782051282051282
# ####best_acc####
# ####################################################### cycle 7 is done
# epoch 0 - train_accuracy : [0.5382153987884521] - validation_loss : [1.3803163766860962] - validation_accuracy : 0.6474358974358975
# ####best_val####
# ####best_acc####
# epoch 1 - train_accuracy : [0.6103803515434265] - validation_loss : [1.0864205360412598] - validation_accuracy : 0.6826923076923077
# ####best_val####
# ####best_acc####
# epoch 2 - train_accuracy : [0.7013863921165466] - validation_loss : [0.9295796155929565] - validation_accuracy : 0.717948717948718
# ####best_val####
# ####best_acc####
# epoch 3 - train_accuracy : [0.6988979578018188] - validation_loss : [0.8886433243751526] - validation_accuracy : 0.7532051282051282
# ####best_val####
# ####best_acc####
# epoch 4 - train_accuracy : [0.7678635120391846] - validation_loss : [0.7539925575256348] - validation_accuracy : 0.7980769230769231
# ####best_val####
# ####best_acc####
# epoch 5 - train_accuracy : [0.7550657391548157] - validation_loss : [0.7502116560935974] - validation_accuracy : 0.7628205128205128
# ####best_val####
# epoch 6 - train_accuracy : [0.8016352653503418] - validation_loss : [0.7238301038742065] - validation_accuracy : 0.8173076923076923
# ####best_val####
# ####best_acc####
# epoch 7 - train_accuracy : [0.7746178507804871] - validation_loss : [0.7530208230018616] - validation_accuracy : 0.7916666666666666
# epoch 8 - train_accuracy : [0.8243867754936218] - validation_loss : [0.699894368648529] - validation_accuracy : 0.8237179487179487
# ####best_val####
# ####best_acc####
# epoch 9 - train_accuracy : [0.796302855014801] - validation_loss : [0.6583458781242371] - validation_accuracy : 0.8108974358974359
# ####best_val####
# epoch 10 - train_accuracy : [0.8414503931999207] - validation_loss : [0.6282715797424316] - validation_accuracy : 0.8333333333333334
# ####best_val####
# ####best_acc####
# epoch 11 - train_accuracy : [0.8137220144271851] - validation_loss : [0.6753250956535339] - validation_accuracy : 0.7948717948717948
# epoch 12 - train_accuracy : [0.8560255765914917] - validation_loss : [0.5782052278518677] - validation_accuracy : 0.8589743589743589
# ####best_val####
# ####best_acc####
# epoch 13 - train_accuracy : [0.8282971978187561] - validation_loss : [0.6557645797729492] - validation_accuracy : 0.8333333333333334
# epoch 14 - train_accuracy : [0.8688233494758606] - validation_loss : [0.6459122896194458] - validation_accuracy : 0.8269230769230769
# epoch 15 - train_accuracy : [0.8336295485496521] - validation_loss : [0.6561581492424011] - validation_accuracy : 0.8108974358974359
# epoch 16 - train_accuracy : [0.899040162563324] - validation_loss : [0.4967832863330841] - validation_accuracy : 0.8717948717948718
# ####best_val####
# ####best_acc####
# epoch 17 - train_accuracy : [0.8766441345214844] - validation_loss : [0.5033422708511353] - validation_accuracy : 0.8653846153846154
# epoch 18 - train_accuracy : [0.921791672706604] - validation_loss : [0.5069020390510559] - validation_accuracy : 0.8589743589743589
# epoch 19 - train_accuracy : [0.8865979313850403] - validation_loss : [0.48809877038002014] - validation_accuracy : 0.8653846153846154
# ####best_val####
# epoch 20 - train_accuracy : [0.9228581786155701] - validation_loss : [0.4859420657157898] - validation_accuracy : 0.8685897435897436
# ####best_val####
# epoch 21 - train_accuracy : [0.8961962461471558] - validation_loss : [0.4832077920436859] - validation_accuracy : 0.8782051282051282
# ####best_val####
# ####best_acc####
# epoch 22 - train_accuracy : [0.9313899874687195] - validation_loss : [0.47214868664741516] - validation_accuracy : 0.8846153846153846
# ####best_val####
# ####best_acc####
# epoch 23 - train_accuracy : [0.8951297402381897] - validation_loss : [0.4715636372566223] - validation_accuracy : 0.875
# ####best_val####
# epoch 24 - train_accuracy : [0.9328119158744812] - validation_loss : [0.4679233431816101] - validation_accuracy : 0.8589743589743589
# ####best_val####
# epoch 25 - train_accuracy : [0.9011731147766113] - validation_loss : [0.4823596179485321] - validation_accuracy : 0.8621794871794872
# epoch 26 - train_accuracy : [0.9345893859863281] - validation_loss : [0.47461554408073425] - validation_accuracy : 0.8685897435897436
# epoch 27 - train_accuracy : [0.9125488996505737] - validation_loss : [0.4852161407470703] - validation_accuracy : 0.875
# epoch 28 - train_accuracy : [0.9420547485351562] - validation_loss : [0.4701922833919525] - validation_accuracy : 0.8621794871794872
# epoch 29 - train_accuracy : [0.9146818518638611] - validation_loss : [0.48590028285980225] - validation_accuracy : 0.8717948717948718
# epoch 30 - train_accuracy : [0.9420547485351562] - validation_loss : [0.46836695075035095] - validation_accuracy : 0.8717948717948718
# epoch 31 - train_accuracy : [0.9022396206855774] - validation_loss : [0.4742726981639862] - validation_accuracy : 0.8621794871794872
